# %% [markdown]
# <a href="https://colab.research.google.com/github/lucenarpinto-ops/laboratorio-de-informatica/blob/main/teste_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Digitar varios numeros ate que se digita "S" para sair
# encontrar a maior sequencia consecutiva de numeros digitada e armazenar em outra lista
# apresentar a quantidade e a sequencia

numeros = []
lista1 =[]
lista2 =[]

print("Digite números (digite 's' para finalizar):")

while True:

    entrada = input("Digite um número: ")
    if entrada.lower() == 's':
        break

    else:
        numero = int(entrada)
        #valor > numero
        numeros.append(numero)

media = sum(numeros) / len(numeros)

for i in range(0,len(numeros)):
  valor = numeros[i]
  valor1 = numeros[i] - 1
  if valor1 == (numeros[i]):
    lista1.append(numeros[i])

  # if media > numeros[i]:
  #   lista1.append(numeros[i])
  # else:
  #   lista2.append(numeros[i])

print(f' a sequencia digitada é {numeros}')
print(lista1)
print(len(lista1))
# print(lista2)
# print(media)
